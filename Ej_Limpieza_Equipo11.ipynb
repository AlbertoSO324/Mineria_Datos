# %% [markdown]
# # Equipo No.11

# %% [markdown]
# ### Grupo:      003
#              Lunes: 6pm~9pm
# ### Integrantes:
#              GARZA AMAYA HECTOR YAIR
#              SAUCEDO OROZCO ALBERTO
#              GONZALEZ CURIEL SEBASTIAN
#              ALSINA RODRIGUEZ BRANDON DANIEL

# %% [markdown]
# ## FIFA 19 (https://www.kaggle.com/karangadiya/fifa19)

# %% [markdown]
# ### Importación de Librerias

# %%
import pandas as pd
import numpy as np
import json
import zipfile as zp

# %% [markdown]
# ### Carga de bases de datos

# %%
fifa = pd.read_csv("C:\\Users\\alber\\OneDrive - uanl.edu.mx\\UNIVERSIDAD\\UNIVERSIDAD\\TAREAS\\Mineria de Datos\\Practica 1.Limpieza csv\\archive (1)\data.csv")
covid = pd.read_csv("C:\\Users\\alber\\OneDrive - uanl.edu.mx\\UNIVERSIDAD\\UNIVERSIDAD\\TAREAS\\Mineria de Datos\\Practica 1.Limpieza csv\\archive\\country_wise_latest.csv")

# %% [markdown]
# ### Visualización de datos e información (FIFA)

# %%
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.tail(5)
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %% [markdown]
# ### Descripción de columnas

# %%
#Revisar la cantidad de filas y columnas
fifa.shape
# Out:
# (18207, 89)

# %%
#Mostrar nombres de las columnas de la base de datos
fifa.columns
#Tenemos muchas columnas no relevantes
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#Clasificación de datos por columna
fifa.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
#Se revisa si la base de datos contiene valores nulos y se hace la suma por columna
fifa.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %% [markdown]
# ### Guardar datos con agrupaciones

# %%
#Se eliminan las columnas que contengan celdas vacias
fifa_lleno= fifa.dropna(axis=1)
#Se guarda el cambio en otro .csv
fifa_lleno.to_csv
# Out:
# <bound method NDFrame.to_csv of        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# ...

# %%
#Verificar que haya funcionado la anterior eliminacion de columnas con valores nulos
fifa_lleno.isnull().any()
# Out:
# Unnamed: 0     False
# ID             False
# Name           False
# Age            False
# Photo          False
# Nationality    False
# Flag           False
# Overall        False
# Potential      False
# Club Logo      False
# Value          False
# Wage           False
# Special        False
# dtype: bool

# %%
#Ultimos cambios a la nueva base de datos
fifa_lleno=fifa_lleno.rename(columns={'Overall':'Calification Overall'})
fifa_lleno=fifa_lleno.rename(columns={'Potential':'Calification Potential'})
fifa_lleno=fifa_lleno.drop('Special',axis=1)

# %%
fifa_lleno
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %% [markdown]
# ## COVID-19 Dataset (https://www.kaggle.com/imdevskp/corona-virus-report)

# %% [markdown]
# ### Visualización de datos e información (COVID)

# %%
covid.head(5)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
covid.tail(5)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
covid.shape
# Out:
# (187, 15)

# %%
#Las columnas de esta base de datos permanecera sin cambios por la relevancia de sus datos
covid.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
#Se crea nueva agrupación para los paises con casos confirmados mayores a 10,000
covid_10000=covid[covid['Confirmed']>10000]
#Guardar la anterior agrupación en .csv
covid_10000.to_csv
# Out:
# <bound method NDFrame.to_csv of            Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             Afghanistan      36263    1269      25198    9796        106
# 2                 Algeria      27973    1163      18837    7973        616
# 6               Argentina     167416    3059      72575   91782       4890
# 7                 Armenia      37390     711      26665   10014         73
# 8               Australia      15303     167       9311    5825        368
# ..                    ...        ...     ...        ...     ...        ...
# 176  United Arab Emirates      59177     345      52510    6322        264
# 177        United Kingdom     301708   45844       1437  254427        688
# 179            Uzbekistan      21209     121      11674    9414        678
# 180             Venezuela      15988     146       9959    5883        525
# 182    West Bank and Gaza      10621      78       3752    6791        152
#
# ...

# %%
covid_10000.shape
# Out:
# (80, 15)
